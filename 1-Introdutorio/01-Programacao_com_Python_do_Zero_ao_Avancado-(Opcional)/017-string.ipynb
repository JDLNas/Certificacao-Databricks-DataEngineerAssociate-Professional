# %%
nome = "José"
letra = nome[2]
print(letra)
print(len(nome))

# %%
nome = "Curso de Python"
instrutor = "José"
print(nome + " com " + instrutor)

# %%
frase = "Vamos aprender Python hoje."
palavras = frase.split()
print(palavras[1])

for palavra in palavras:
  print(palavra)

# %%
frase = "Vamos aprender Python hoje."
palavras = frase.split()
print(palavras[1])

for letra in frase:
  print(letra)

# %%
email = input("Digite seu email: ")
arroba = email.find("@")
print(arroba)

usuario = email[:arroba]
dominio = email[arroba+1:]
print("Usuario: " + usuario)
print("Dominio: " + dominio)

# %%
produtos = "carbonato de sódio e óxido de zinco"
print("sódio" in produtos)
print("magnésio" in produtos)
print("magnésio" not in produtos)

# %%
item = "hipoclorito"
pos = item.find("clor")
print(pos)
pos = item.find("flu")
print(pos)

# %%
objeto_celeste = "galáxia esPiral M31"
print(objeto_celeste.upper())
print(objeto_celeste.lower())
print(objeto_celeste.capitalize())
print(objeto_celeste.title())

# %%
suplemento = "cloreto de magnésio"
n_suplemento = suplemento.replace("magnésio", "zinco")
print(n_suplemento)

# %%
frase = "  Ômega 3 é bom para a saúde!   "
print(frase.strip())
print(frase.lstrip())
print(frase.rstrip())

# %%
fruta = "Abacate"
print(fruta.center(20, "-"))
print(fruta.ljust(20, "-"))
print(fruta.rjust(20))
print(fruta.zfill(20))

# %%
p = "Bob Esponja"
print(p.startswith("Bo"))
print(p.endswith("ja"))

# %%
texto = """
Docstring é uma string que fica no início de um código, que pode ser usada para documentar o código.
"""
print(texto)
